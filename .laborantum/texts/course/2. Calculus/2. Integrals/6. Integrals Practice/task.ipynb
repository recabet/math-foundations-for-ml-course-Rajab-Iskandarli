# %%
import numpy as np
import matplotlib.pyplot as plt
import json_tricks

answer = {}

# %% [markdown]
# ## Task 1. Analytical integrals
#
# Find formulae of integrals for the functions below from $1$ to $x$:
#
# $\int_1^x f(x) dx$

# %%
def f1(x):
    return 3 * x**2

def f2(x):
    return 5*x**4 - 2*x**3 + x

def f3(x):
    return np.cos(x) ** 2 + 2 * np.sin(x) * np.cos(x)

def f4(x):
    return x * np.exp(x**2)

def f5(x):
    return x * np.log(x)

def f6(x):
    return x / (x**2 + 1)

def f7(x):
    return np.exp(x) * np.sin(x)

def f8(x):
    return np.exp(x) * x

def f9(x):
    return x ** 2 * np.log(x)

def f10(x):
    return np.sin(x) / (1 + np.cos(x))

# %%
def int_f1(x):
    res = x**3-1
    
    return res

def int_f2(x):
    res = x**5-x**4/2+x**2/2-(1)
  
    return res

def int_f3(x):
    res = np.sin(2*x)/4+x/2-np.cos(2*x)/2-(np.sin(2)/4-np.cos(2)/2+1/2)
    return res

def int_f4(x):
    res = 1/2*np.exp(x**2)-np.exp(1)/2
    return res

def int_f5(x):
    res = np.log(x)*x**2/2-x**2/4+1/4
    return res

def int_f6(x):
    res = 1/2*np.log((x**2+1)/2)
    return res

def int_f7(x):
    res = (np.exp(x) / 2) * (np.sin(x) - np.cos(x)) - (np.exp(1) / 2) * (np.sin(1) - np.cos(1))
    return res

def int_f8(x):
    res = x * np.exp(x) - np.exp(x)
    return res

def int_f9(x):
    res = x**3/3*np.log(x)-x**3/9+1/9
    return res

def int_f10(x):
    res = np.log((1 + np.cos(1)) / (1 + np.cos(x)))
    return res

# %%
fs = [f1, f2, f3, f4, f5, f6, f7, f8, f9, f10]
int_fs = [int_f1, int_f2, int_f3, int_f4, int_f5, int_f6, int_f7, int_f8, int_f9, int_f10]

x = np.linspace(1, 5, 100)
answer['integrals'] = [int_f(x) for int_f in int_fs]

# %% [markdown]
# ## Task 2. Rectangle approximation
#
# Write a function that calculates approximate integral with $N$ eqidistant rectangles. Use middle point approximation for the best result.

# %%
def approx_int_squares(f, a, b, n):
    dx = (b - a) / n
    area = 0
    for i in range(1,n+1):
        mid_x = a + (i - 0.5) * dx
        area += f(mid_x) * dx
    return area

# %% [markdown]
# ## Task 3. Trapezoid approximation
#
# Write a function that calculates approximate integral with $N$ eqidistant trapezoids

# %%
def approx_int_trapezoids(f, a, b, n):
    dx = (b - a) / n
    area=0
    for i in range(n):
        area += f(a + i * dx)+f(a+(i+1)*dx)
    area *= dx/2

    return area

# %%
for x in np.linspace(1, 5):
    answer['squares'] = [approx_int_squares(f, 1, x, 10) for f in fs]
    answer['trapezoids'] = [approx_int_squares(f, 1, x, 10) for f in fs]

# %% [markdown]
# ## Step 4: Visualization
#
# First of all, there will be a vizualization of trapezoids and rectangles that are used to approximate the integrals.

# %%
# You can change this N afterwards to check how good is the
# approximation and to check how the trapezoids and rectangles
# fill the area under the curve
N = 10
b = 2

plt.figure(figsize=(10, 20))
for index in range(len(fs)):
    print('===', str(index))
    f = fs[index]
    int_f = int_fs[index]
    plt.subplot(10, 1, index + 1)
    x = np.linspace(1, b, 1000)
    plt.plot(x, f(x), linewidth=4)

    x = np.linspace(1, b, N)
    squares_x = []
    squares_y = []
    for index in range(len(x) - 1):
        squares_x.extend([x[index], x[index], x[index + 1], x[index + 1]])
        squares_y.extend([0, f((x[index] + x[index + 1])/2), f((x[index] + x[index + 1])/2), 0])

    plt.plot(squares_x, squares_y)
    plt.grid()
    plt.axhline(0, color='black', linewidth=0.8)

    x = np.linspace(1, b, N)
    trapezoids_x = []
    trapezoids_y = []
    for index in range(len(x) - 1):
        trapezoids_x.extend([x[index], x[index], x[index + 1], x[index + 1]])
        trapezoids_y.extend([0, f(x[index]), f(x[index + 1]), 0])

    plt.plot(trapezoids_x, trapezoids_y)
    # plt.grid()
    plt.axhline(0, color='black', linewidth=0.8)
    plt.legend(['function', 'rectangles', 'trapezoids'])

    int_f_exact = int_f(2)
    int_f_squares = approx_int_squares(f, 1, 2, N)
    int_f_trapezoids = approx_int_trapezoids(f, 1, 2, N)

    
    print(int_f_exact)
    print(int_f_squares)
    print(int_f_trapezoids)
    print('===')
# Out:
# === 0
# 7
# 6.9975000000000005
# 7.005
# ===
# === 1
# 25.0
# 24.949181250000006
# 25.101650000000006
# ===
# === 2
# 0.20222341162483215
# 0.20172653768969406
# 0.20321666260934734
# ===
# === 3
# 25.939934102342594
# 25.740089695906782
# 26.340907912890124
# ===
# === 4
# 0.6362943611198906
# 0.6360056407612503
# 0.6368718797887363
# ===
# === 5
# 0.4581453659370775
# 0.45819519178593104
# 0.45804556496413174
# ===
# === 6
# 4.487560335402326
# 4.487604875539899
# 4.487469385297051
# ===
# === 7
# 7.38905609893065
# 7.38208818102075
# 7.402994649502211
# ===
# === 8
# 1.0706147037154097
# 1.0690426703317775
# 1.0737586664241394
# ===
# === 9
# 0.9700844598845829
# 0.9696421030382268
# 0.9709698445536845
# ===

# %% [markdown]
# # Step 5:
#
# Check yourself.
#
# With integrals it is very easy to check yourself whether you found an integral correctly. You only have to differentiate the integral function, and what you should get is the original function that you are integrating.

# %%
# Change the discretization to check whether the derivative converges to the original function
x = np.linspace(1, 2, 100)

for index in range(len(fs)):
    f = fs[index]
    int_f = int_fs[index]
    
    f_vals = f(x)
    int_f_vals = int_f(x)

    d_int_f_approx = (int_f_vals[1:] - int_f_vals[:-1]) / (x[1:] - x[:-1])

    plt.plot(d_int_f_approx - f_vals[:-1])

# %%
json_tricks.dump(answer, '.answer.json')
# Out:
# '{"integrals": [{"__ndarray__": [0.0, 0.12617553970477147, 0.2625417525937883, 0.40949439296546686, 0.5674292151182261, 0.7367419733504825, 0.9178284219606534, 1.111084315247156, 1.3169054075084072, 1.5356874530428257, 1.767826206148826, 2.0137174211248285, 2.273756852269249, 2.548340253880505, 2.8378633802570143, 3.1427219856971913, 3.46331182449946, 3.800028650962229, 4.153268219383921, 4.523426284062954, 4.910898599297743, 5.316080919386706, 5.739368998628257, 6.181158591320822, 6.641845451762808, 7.121825334252641, 7.621493993088729, 8.141247182569495, 8.681480656993362, 9.242590170658735, 9.824971477864036, 10.429020332907694, 11.055132490088113, 11.703703703703706, 12.375129728052897, 13.069806317434114, 13.788129226145756, 14.530494208486248, 15.297297018754016, 16.088933411247467, 16.905799140265014, 17.74828996010508, 18.616801625066092, 19.51172988944645, 20.433470507544577, 21.382419233658904, 22.35897182208784, 23.363524027129788, 24.396471603083175, 25.458210304246432, 26.549135884917952, 27.669644099396177, 28.820130701979497, 30.00099144696635, 31.212622088655152, 32.45541838134431, 33.729776079332254, 35.03609093691739, 36.37475870839813, 37.74617514807292, 39.150736010240145, 40.58883704919825, 42.06087401924562, 43.567242674680706, 45.1083387698019, 46.68455805890762, 48.29629629629631, 49.94394923626635, 51.627912633116196, 53.34858224114423, 55.106353814648905, 56.9016231079286, 58.734785875281744, 60.60623787100679, 62.5163748494021, 64.46559256476615, 66.45428677139728, 68.48285322359393, 70.55168767565466, 72.66118588187764, 74.81174359656148, 77.00375657400454, 79.23762056850516, 81.51373133436189, 83.83248462587308, 86.1942761973371, 88.59950180305246, 91.04855719731756, 93.54183813443072, 96.07974036869054, 98.66265965439521, 101.29099174584327, 103.96513239733325, 106.68547736316333, 109.45242239763209, 112.26636325503793, 115.12769568967917, 118.03681545585435, 120.99411830786185, 124.0], "dtype": "float64", "shape": [100]}, {"__ndarray__": [0.0, 0.17439958285309087, 0.376623623388765, 0.6102860395448175, 0.8793144131086659, 1.187962910988181, 1.5408252064825314, 1.9428474005530183, 2.399340943093921, 2.9159955542033282, 3.49889214545398, 4.154515741164117, 4.8897683996683, 5.711982134588263, 6.628931836103748, 7.648848192223339, 8.780430610055328, 10.032860137078494, 11.415812382413026, 12.93947043809128, 14.614537800328677, 16.452251290794504, 18.46439397788277, 20.663308097983087, 23.061907976751378, 25.673692950380907, 28.512760286872904, 31.593818107307612, 34.93219830711502, 38.54386947734562, 42.445449825941424, 46.65422009900674, 51.18813650207891, 56.06584362139919, 61.306687345183754, 66.93072778489439, 72.95875219650918, 79.41228790179372, 86.31361520957172, 93.6857803369958, 101.55260833081827, 109.93871598866242, 118.86952478029293, 128.37127376888657, 138.47103253230364, 149.19671408435838, 160.57708779608978, 172.64179231703238, 185.42134849648758, 198.94717230479418, 213.2515877545987, 228.36783982212737, 244.3301073684557, 261.1735160607804, 278.9341512936897, 297.64907111043374, 317.3563191241968, 338.094937439366, 359.9049795728047, 382.8275233751214, 406.9046839519409, 432.1796265851763, 458.6965796542979, 486.5008475576062, 515.6388236335006, 546.1580030817523, 578.1069958847738, 611.5355397288894, 646.4945129256083, 683.0359473328915, 721.2130412764274, 761.0801724708983, 802.6929109412547, 846.1080319439842, 891.3835288883818, 938.5786262578235, 987.7537925310319, 1038.9707531033541, 1092.2925032080304, 1147.7833208374564, 1205.5087796644682, 1265.5357619636025, 1327.9324715323714, 1392.7684466125352, 1460.1145728113688, 1530.0430960229332, 1602.627635349353, 1677.9431960220772, 1756.0661823231549, 1837.0744105065128, 1921.0471217192073, 2008.0649949227184, 2098.210159814209, 2191.5662097477853, 2288.2182146557925, 2388.2527339700628, 2491.7578295431967, 2598.823078569837, 2709.53958650793, 2824.0], "dtype": "float64", "shape": [100]}, {"__ndarray__": [0.0, 0.04708269015776245 ...
